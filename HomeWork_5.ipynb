# %%
from math import factorial
import numpy as np

# %%
def combinations(n, k):
    return int(factorial(n) / (factorial(k) * factorial(n - k)))

# %% [markdown]
# ### 1. Известно, что генеральная совокупность распределена нормально со средним квадратическим отклонением, равным 16. Найти доверительный интервал для оценки математического ожидания a с надежностью 0.95, если выборочная средняя M = 80, а объем выборки n = 256.

# %%
s = 16
M = 80
n = 256
z = 1.96 # (1 - 0.95)/2 = 0.025
x1 = M + z * s / (n) ** 0.5
x2 = M - z * s / (n) ** 0.5
print(f'Доверительный интервал: {x2, x1}')
# Out:
# Доверительный интервал: (78.04, 81.96)

# %% [markdown]
# ### 2. В результате 10 независимых измерений некоторой величины X, выполненных с одинаковой точностью, получены опытные данные: 6.9, 6.1, 6.2, 6.8, 7.5, 6.3, 6.4, 6.9, 6.7, 6.1. Предполагая, что результаты измерений подчинены нормальному закону распределения вероятностей, оценить истинное значение величины X при помощи доверительного интервала, покрывающего это значение с доверительной вероятностью 0,95.

# %%
x = [6.9, 6.1, 6.2, 6.8, 7.5, 6.3, 6.4, 6.9, 6.7, 6.1]
s = np.std(x, ddof=1)
t = 2.26 
X = sum(x) / len(x)
print(X)
x1 = X - t * s / (len(x)) ** 0.5
x2 = X + t * s / (len(x)) ** 0.5
print(f'Доверительный интервал: {x1, x2}')
# Out:
# 6.589999999999999
# Доверительный интервал: (6.267823367976163, 6.912176632023835)

# %% [markdown]
# ### 3. Утверждается, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм. Используя односторонний критерий с α=0,05, проверить эту гипотезу, если в выборке из n=100 шариков средний диаметр оказался равным 17.5 мм, а дисперсия известна и равна 4 мм.

# %%
'''H0: Выборка шариков - часть генеральной совокупности'''

m = 17.5 - 17.0
z_m = m / (4 ** 0.5 / 100 ** 0.5)
print(z_m) # получаем 2.5

'''Односторонний критерий для вероятности 0.95 z = 1.65 Т.о. с вероятностью ошибки 5% можем сказать, что в работе станка произшла ошибка'''
# Out:
# 2.5
# 'Односторонний критерий для вероятности 0.95 z = 1.65 Т.о. с вероятностью ошибки 5% можем сказать, что в работе станка произшла ошибка'

# %% [markdown]
# ### 4. Продавец утверждает, что средний вес пачки печенья составляет 200 г. Из партии извлечена выборка из 10 пачек. Вес каждой пачки составляет: 202, 203, 199, 197, 195, 201, 200, 204, 194, 190. Известно, что их веса распределены нормально. Верно ли утверждение продавца, если учитывать, что доверительная вероятность равна 99%?

# %%
'''H0: продавец не врет'''
x = [202, 203, 199, 197, 195, 201, 200, 204, 194, 190]
X = sum(x) / len(x)
print(f'средний вес пачки из выборки: {X}')
m = 200 - X
s = np.std(x, ddof=1)
print(f'Нeсмещенная оценка std = {s}')
t = m / (s / 10 ** 0.5)
print(t)

'''Критерий Стьюдента для доверит вероятности 99 % (а = 0.5% так как исходно не знаем больше или меньше) и ст свободы 9 = 3.25 \n Т.о. с вероятностью ошибиться в 1% могу доверять словам продавца, что пачка печенья будет весить 200 гр'''
# Out:
# средний вес пачки из выборки: 198.5
# Нeсмещенная оценка std = 4.453463071962462
# 1.0651074037450896
# 'Критерий Стьюдента для доверит вероятности 99 % (а = 0.5% так как исходно не знаем больше или меньше) и ст свободы 9 = 3.25 \n Т.о. с вероятностью ошибиться в 1% могу доверять словам продавца, что пачка печенья будет весить 200 гр'
